# %%
#Problem 13

# %%
x = var('x')

# %%
def f(x): return (1/sqrt(2*pi))*exp(-x^2/2)

# %%
p = []

# %%
p.append(plot(f(x),(x,-2,-1.37), color='blue', legend_label='f(x)'))

# %%
p.append(plot(f(x),(x,-1.37,0), color='blue', fill=true))

# %%
p.append(plot(f(x),(x,0,2), color='blue'))

# %%
sum(p)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
int = integral(f(x), x, -1.37, 0)

# %%
int
# Out:
# 1/2*erf(0.685*sqrt(2))

# %%
numerical_approx(int)
# Out:
# 0.414656549178033

# %% [markdown]
# ---

# %%
#Problem 17

# %%
x = var('x')

# %%
def f(x): return (1/sqrt(2*pi))*exp(-x^2/2)

# %%
p = []

# %%
p.append(plot(f(x),(x,-2,1.35), color='blue', legend_label='f(x)'))

# %%
p.append(plot(f(x),(x,1.35,1.45), color='blue', fill=true))

# %%
p.append(plot(f(x),(x,1.45,2), color='blue'))

# %%
sum(p)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
int = integral(f(x), x, 1.35, 1.45)

# %%
int
# Out:
# 1/4*sqrt(2)*(sqrt(2)*sqrt(pi)*erf(0.725*sqrt(2)) - sqrt(2)*sqrt(pi)*erf(0.675*sqrt(2)))/sqrt(pi)

# %%
numerical_approx(int)
# Out:
# 0.0149787318277536

# %% [markdown]
# ---

# %%
#Problem 21

# %%
x = var('x')

# %%
def f(x): return (1/sqrt(2*pi))*exp(-x^2/2)

# %%
p = []

# %%
p.append(plot(f(x),(x,2,3.01), color='blue', legend_label='f(x)'))

# %%
p.append(plot(f(x),(x,3.01,4), color='blue', fill=true))

# %%
sum(p)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
int = integral(f(x), x, 3.01, oo)

# %%
int
# Out:
# -1/4*sqrt(2)*(sqrt(2)*sqrt(pi)*erf(1.505*sqrt(2)) - sqrt(2)*sqrt(pi))/sqrt(pi)

# %%
numerical_approx(int)
# Out:
# 0.00130623844876950

# %% [markdown]
# ---

# %%
#Problem 25

# %%
x = var('x')

# %%
def f(x): return 1/(sigma*sqrt(2*pi))*exp(-0.5*((x-mu)/sigma)^2)

# %%
mu = 22

# %%
sigma = 5

# %%
p = []

# %%
p.append(plot(f(x),(x,14,24), color='blue', legend_label='f(x)'))

# %%
p.append(plot(f(x),(x,24,30), color='blue', fill=true))

# %%
sum(p)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
int = integral(f(x), x, 24, 30)

# %%
int
# Out:
# 197041/12606286676*sqrt(2)*(sqrt(2)*sqrt(pi)*erf(4/5*sqrt(2))*e^(242/25) - sqrt(2)*sqrt(pi)*erf(1/5*sqrt(2))*e^(242/25))/sqrt(pi)

# %%
numerical_approx(int)
# Out:
# 0.289778966690118

# %% [markdown]
# ---

# %%
#Problem 57

# %%
x = var('x')

# %%
m = var('m')

# %%
def f(x): return (1/2)*x

# %%
p = []

# %%
p.append(plot(f(x),(x,0,2), color='blue', fill=true, legend_label='f(x)'))

# %%
p.append(plot(f(x),(x,2,4), color='blue'))

# %%
sum(p)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
int = integral(f(x), x, 0, m)

# %%
int
# Out:
# 1/4*m^2

# %%
(int - 0.5).roots()
# Out:
# [(-sqrt(2), 1), (sqrt(2), 1)]

# %%
numerical_approx(sqrt(2))
# Out:
# 1.41421356237310

# %%
(int - 1).roots()
# Out:
# [(-2, 1), (2, 1)]

# %%
p = []

# %%
p.append(plot(f(x),(x,0,sqrt(2)), color='blue', fill=true, legend_label='f(x)'))

# %%
p.append(plot(f(x),(x,sqrt(2),2), color='blue'))

# %%
sum(p)
# Out:
# Graphics object consisting of 3 graphics primitives

# %% [markdown]
# ---

# %%
#Problem 64

# %%
x = var('x')

# %%
def f(x): return exp(-x^2)

# %%
plot(f(x),(x,-5,5), color='blue', fill=true, legend_label='f(x)')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
int = integral(f(x), x, -oo, oo)

# %%
int
# Out:
# sqrt(pi)
